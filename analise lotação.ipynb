# %% [markdown]
# <a href="https://colab.research.google.com/github/Claudioteste96/analise_lotacao/blob/main/analise%20lota%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Analise de dados usando SQL

# %% [markdown]
# #####Configurando o setup

# %%
# !pip install pandasql

# %%
import pandas as pd
import pandasql as ps

# %% [markdown]
# Lendo as bases de dados

# %%
tb_cargo = pd.read_csv('https://raw.githubusercontent.com/Claudioteste96/analise_lotacao/main/cargo.csv')
tb_departamento = pd.read_csv('https://raw.githubusercontent.com/Claudioteste96/analise_lotacao/main/departamento.csv')
tb_funcionario = pd.read_csv('https://raw.githubusercontent.com/Claudioteste96/analise_lotacao/main/funcionario.csv')
tb_lotacao = pd.read_csv('https://raw.githubusercontent.com/Claudioteste96/analise_lotacao/main/lota%C3%A7ao.csv')

# %% [markdown]
# #Problemas de negocio
#
# 1 Liste os nomes (funcionario e cargo) por departamento com salario e pretensão salarial.

# %%
query = """
select * from tb_cargo
"""

ps.sqldf(query,locals())



query = """
select
fc.nome as  nm_funcionario,
cg.nome as nm_cargo,
fc.pretensao_salarial,
lt.salario
from tb.lotacao as lt
inner join tb_funcionario as fc on fc.id = lt.id_funcionario
inner join tb as cg.id = lt.id_cargo
"""

ps.sqldf(query,locals())
# Out:
#     id  id_funcionario  id_departamento  id_cargo  salario    cadastro  ativo
# 0    1               1                1         1   9000.0  2022-09-01      1
# 1    2               2                2         2   7500.0  2022-09-02      1
# 2    3               3                1         3   5000.0  2022-09-05      1
# 3    4               4                2         4   6500.0  2022-09-06      1
# 4    5               5                1         5   8000.0  2022-09-07      1
# 5    6               6                2         6   7000.0  2022-09-08      1
# 6    7               7                1         1   9000.0  2022-09-09      1
# 7    8               8                2         2   7500.0  2022-09-12      1
# 8    9               9                1         3   5000.0  2022-09-13      1
# 9   10              10                2         4   6500.0  2022-09-14      1
# 10  11              11                1         5   8000.0  2022-09-15      1
# ...

# %% [markdown]
# a consulta resulta na lista dos funcionarios por departamento com salario e pretensao salarial.
#
#   2 liata os funcionarios (nome e salario) que nao sejam pcd e que possuam salario maior que  R$ 4000,00 ordenados pelo maior salario.

# %%
print('Tabela lotação')
display(tb_lotacao.head(2))
print('Tabela funcionario')
display(tb_funcionario.head(2))
# Out:
# Tabela lotação
#    id  id_funcionario  id_departamento  id_cargo  salario    cadastro  ativo
# 0   1               1                1         1   9000.0  2022-09-01   True
# 1   2               2                2         2   7500.0  2022-09-02   True
# Tabela funcionario
#    id   nome  nascimento  pretensao_salarial    pcd
# 0   1  Pedro  1984-05-29              5500.0   True
# 1   2   João  1980-02-01              6000.0  False

# %%
query = """
select
fc.nome,
fc.pcd,
lt.salario
from tb_lotacao as lt
inner join tb_funcionario as fc on fc.id = lt.id_funcionario
where fc.pcd = 0 and lt.salario > 4000
order by lt.salario desc
"""

ps.sqldf(query,locals())
# Out:
#       nome  pcd  salario
# 0  Morgana    0   8000.0
# 1  Dorival    0   8000.0
# 2     João    0   7500.0
# 3  Antonio    0   7500.0
# 4    Julia    0   7000.0
# 5    Lucio    0   7000.0
# 6    Laura    0   6500.0
# 7    Maria    0   5000.0
# 8      Lia    0   5000.0

# %% [markdown]
# ###lista dos funcionarios que não sao pcd e com salario maior que R$ 4000,00
#
#
# 3. liste os cargos  e suas respectivas medias salariais maiores que R$ 5000,00

# %%
print('Tabela cargo')
display(tb_cargo.head(2))
print('Tabela lotação')
display(tb_lotacao.head(2))
# Out:
# Tabela cargo
#    id               nome
# 0   1  Analista de Dados
# 1   2        Programador
# Tabela lotação
#    id  id_funcionario  id_departamento  id_cargo  salario    cadastro  ativo
# 0   1               1                1         1   9000.0  2022-09-01   True
# 1   2               2                2         2   7500.0  2022-09-02   True

# %%
query = """
select
cg.nome as cargo,
avg(lt.salario) as media_salario
from tb_lotacao as lt
inner join tb_cargo as cg on cg.id = lt.id_cargo
group by
cg.nome
having avg(lt.salario) > 5000
"""

ps.sqldf(query,locals())
# Out:
#                  cargo  media_salario
# 0    Analista de Dados         9000.0
# 1    Analista de Infra         8000.0
# 2  Coordenador de Área         6500.0
# 3    Gestor Financeiro         7000.0
# 4          Programador         7500.0

# %% [markdown]
# Resultados
# escrever
